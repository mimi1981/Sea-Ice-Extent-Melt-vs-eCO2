# %% [markdown]
# # Visualization of eCO2 footprint estimates from Mike Berners-Lee's book 'How bad are bananas' in terms of September additional yearly sea ice extent melt as estimated by Notz and Stroeve, 2016 Science study
#
# Creidt: Michelt Tsamados (2019/04/19)

# %%
import pandas as pd
file_name='DataHowBadAreBananas.xlsx'
df = pd.read_excel(io=file_name)#, sheet_name=sheet)
print(df.head(5))  # print first 5 rows of the dataframe
# Out:
#                                 Item  eCO2 (ton/year)    SSIE loss      Sector
# 0                       Text message     1.400000e-08  4.200000e-08       gray
# 1                   Cup of tap water     6.000000e-08  1.800000e-07  rosybrown
# 2       Web search - Google estimate     2.000000e-07  6.000000e-07       gray
# 3      Web search - efficient laptop     7.000000e-07  2.100000e-06       gray
# 4  Web search - power hungry machine     4.500000e-06  1.350000e-05       gray

# %%
df
# Out:
#                                         Item  eCO2 (ton/year)    SSIE loss   \
# 0                               Text message     1.400000e-08  4.200000e-08
# 1                           Cup of tap water     6.000000e-08  1.800000e-07
# 2               Web search - Google estimate     2.000000e-07  6.000000e-07
# 3              Web search - efficient laptop     7.000000e-07  2.100000e-06
# 4          Web search - power hungry machine     4.500000e-06  1.350000e-05
# 5               All world's texts for a year     3.200000e+04  9.600000e+04
# 6            Year's tap water for US citizen     2.300000e-02  6.900000e-02
# 7   Walking through a door (winter New York)     3.000000e-06  9.000000e-06
# 8          Walking through big electric door     8.400000e-02  2.520000e-01
# 9                                 Spam email     3.000000e-07  9.000000e-07
# 10            An email with long attachement     5.000000e-05  1.500000e-04
# 11                 Plastic bag (supermarket)     1.000000e-05  3.000000e-05
# 12                    Plastic bag (reusable)     5.000000e-05  1.500000e-04
# 13                    Apple (seasonal+local)     1.000000e-05  3.000000e-05
# 14                           Apple (average)     8.000000e-05  2.400000e-04
# 15                                    Banana     8.000000e-05  2.400000e-04
# 16                              An hour's TV     1.000000e-04  3.000000e-04
# 17               A mug of tea/coffee (black)     3.000000e-05  9.000000e-05
# 18         A mug of tea/coffee (large latte)     3.000000e-04  9.000000e-04
# 19                             A mile by bus     1.000000e-04  3.000000e-04
# 20                           A mile by train     2.000000e-04  6.000000e-04
# 21                       500 mL water bottle     1.000000e-04  3.000000e-04
# 22               Newspaper (Guardian Weekly)     3.000000e-04  9.000000e-04
# 23                    Newspaper (NYT Sunday)     3.000000e-03  9.000000e-03
# 24                              Pint of beer     5.000000e-03  1.500000e-02
# 25                      Shower (electricity(     5.000000e-04  1.500000e-03
# 26                             A mile by car     1.000000e+03  3.000000e+03
# 27                        A red rose (flown)     2.000000e-03  6.000000e-03
# 28                              pint of milk     7.000000e-04  2.100000e-03
# 29                                    A bath     1.000000e-03  3.000000e-03
# 30                                Kg of rice     5.000000e-03  1.500000e-02
# 31                                  A steak      2.000000e-03  6.000000e-03
# 32                       Light bulb (1 year)     5.000000e-01  1.500000e+00
# 33                             Pair of shoes     1.000000e-02  3.000000e-02
# 34                      A night out in hotel     2.400000e-02  7.200000e-02
# 35                     A cell phone (1 year)     1.000000e+00  3.000000e+00
# 36                    A mid distance flight      5.000000e-01  1.500000e+00
# 37                          Christmas excess     2.500000e-01  7.500000e-01
# 38                                   An iMac     7.500000e-01  2.250000e+00
# 39                     A mortgage (per year)     8.000000e-01  2.400000e+00
# 40                               Long flight     5.000000e+00  1.500000e+01
# 41                    A person (UK per year)     1.500000e+01  4.500000e+01
# 42                    A person (US per year)     3.000000e+01  9.000000e+01
# 43                 A person (China per year)     3.000000e+00  9.000000e+00
# 44                                 A new car     1.000000e+01  3.000000e+01
# 45                                  A house      8.000000e+01  2.400000e+02
# 46                            Having a child     5.000000e+02  1.500000e+03
# 47                   1 acre of deforastation     1.500000e+02  4.500000e+02
# 48                              A University     7.200000e+04  2.160000e+05
# 49                   A volcano (Mpount Etna)     1.000000e+06  3.000000e+06
# 50                                 World Cup     3.000000e+06  9.000000e+06
# 51                             A forest fire     2.000000e+08  6.000000e+08
# 52                                     A war     1.000000e+09  3.000000e+09
# 53                                 The world     5.000000e+10  1.500000e+11
#
#        Sector
# 0        gray
# 1   rosybrown
# 2        gray
# 3        gray
# 4        gray
# 5   rosybrown
# 6        blue
# 7   rosybrown
# 8   rosybrown
# 9        gray
# 10       gray
# 11  rosybrown
# 12  rosybrown
# 13      green
# 14      green
# 15      green
# 16  rosybrown
# 17      green
# 18      green
# 19       blue
# 20       blue
# 21      green
# 22  rosybrown
# 23  rosybrown
# 24      green
# 25  rosybrown
# 26       blue
# 27  rosybrown
# 28      green
# 29  rosybrown
# 30      green
# 31      green
# 32  rosybrown
# 33  rosybrown
# 34  rosybrown
# 35       gray
# 36       blue
# 37  rosybrown
# 38       gray
# 39  rosybrown
# 40       blue
# 41     orange
# 42     orange
# 43     orange
# 44       blue
# 45  rosybrown
# 46     orange
# 47      green
# 48  rosybrown
# 49     orange
# 50  rosybrown
# 51     orange
# 52     orange
# 53     orange

# %%
df['Item'][:]
# Out:
# 0                                 Text message
# 1                             Cup of tap water
# 2                 Web search - Google estimate
# 3                Web search - efficient laptop
# 4            Web search - power hungry machine
# 5                 All world's texts for a year
# 6              Year's tap water for US citizen
# 7     Walking through a door (winter New York)
# 8            Walking through big electric door
# 9                                   Spam email
# 10              An email with long attachement
# 11                   Plastic bag (supermarket)
# 12                      Plastic bag (reusable)
# 13                      Apple (seasonal+local)
# 14                             Apple (average)
# 15                                      Banana
# 16                                An hour's TV
# 17                 A mug of tea/coffee (black)
# 18           A mug of tea/coffee (large latte)
# 19                               A mile by bus
# 20                             A mile by train
# 21                         500 mL water bottle
# 22                 Newspaper (Guardian Weekly)
# 23                      Newspaper (NYT Sunday)
# 24                                Pint of beer
# 25                        Shower (electricity(
# 26                               A mile by car
# 27                          A red rose (flown)
# 28                                pint of milk
# 29                                      A bath
# 30                                  Kg of rice
# 31                                    A steak
# 32                         Light bulb (1 year)
# 33                               Pair of shoes
# 34                        A night out in hotel
# 35                       A cell phone (1 year)
# 36                      A mid distance flight
# 37                            Christmas excess
# 38                                     An iMac
# 39                       A mortgage (per year)
# 40                                 Long flight
# 41                      A person (UK per year)
# 42                      A person (US per year)
# 43                   A person (China per year)
# 44                                   A new car
# 45                                    A house
# 46                              Having a child
# 47                     1 acre of deforastation
# 48                                A University
# 49                     A volcano (Mpount Etna)
# 50                                   World Cup
# 51                               A forest fire
# 52                                       A war
# 53                                   The world
# Name: Item, dtype: object

# %%
df['eCO2 (ton/year)'][:]
# Out:
# 0    1.400000e-08
# 1    6.000000e-08
# 2    2.000000e-07
# 3    7.000000e-07
# 4    4.500000e-06
# 5    3.200000e+04
# 6    2.300000e-02
# 7    3.000000e-06
# 8    8.400000e-02
# Name: eCO2 (ton/year), dtype: float64

# %%
df['SSIE loss '][:]
# Out:
# 0    4.200000e-08
# 1    1.800000e-07
# 2    6.000000e-07
# 3    2.100000e-06
# 4    1.350000e-05
# 5    9.600000e+04
# 6    6.900000e-02
# 7    9.000000e-06
# 8    2.520000e-01
# Name: SSIE loss , dtype: float64

# %%
df['Sector'][:]
# Out:
# 0         gray
# 1         blue
# 2         gray
# 3         gray
# 4         gray
# 5         gray
# 6         blue
# 7    rosybrown
# 8    rosybrown
# Name: Sector, dtype: object

# %%
plt.figure(figsize=(10,10))
plt.loglog()
for i,type in enumerate(df['Item']):
    x = df['eCO2 (ton/year)'][i]
    y = df['SSIE loss '][i]
    c = df['Sector'][i]
    print(type,x,y,c)
    plt.scatter(x, y, marker='.', color='black')
    plt.text(x+0.1*x, y+0.*y, type, color=c,fontsize=12)
#plt.title('3 metre squared of September Sea Ice Extent Melt per ton of eCO2 emitted',fontsize=24)
# Set x-axis label
plt.xlabel('eCO2 (ton/year)',fontsize=24)
#plt.xscale('log')
# Set y-axis label
plt.ylabel('SSIE melt (m^2)',fontsize=24)


x = 30*np.random.randn(10000)
mu = x.mean()
median = np.median(x)
sigma = x.std()

#textstr = '\n'.join(('Housing',colour=rosybrow,('Food',colour='blue'),('Communication',colour='gray'))


textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\mathrm{median}=%.2f$' % (median, ),
    r'$\sigma=%.2f$' % (sigma, )))

#plt.hist(x, 50)
# these are matplotlib.patch.Patch properties
#props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
plt.text(1e-8, 1e11, 'Food / Water', color='green',fontsize=24)
plt.text(1e-8, 1e11/8., 'Communications', color='gray',fontsize=24)
plt.text(1e-8, 1e11/64., 'Commercial/Residential', color='rosybrown',fontsize=24)
plt.text(1e-8, 1e11/8./64., 'Transport', color='blue',fontsize=24)
plt.text(1e-8, 1e11/64./64., 'Various', color='orange',fontsize=24)

plt.text(2e-1, 2e-8, 'Data: How Bad Are Bananas by Mike Berners-Lee', color='black',fontsize=12)
plt.text(2e2, 2e11, 'Credit:@micheltsamados', color='black',fontsize=12)

plt.show()
# Out:
# Text message 1.4e-08 4.2e-08 gray
# Cup of tap water 6e-08 1.7999999999999997e-07 rosybrown
# Web search - Google estimate 2e-07 6e-07 gray
# Web search - efficient laptop 7e-07 2.1e-06 gray
# Web search - power hungry machine 4.5e-06 1.35e-05 gray
# All world's texts for a year 32000.0 96000.0 rosybrown
# Year's tap water for US citizen 0.023 0.069 blue
# Walking through a door (winter New York) 3e-06 9e-06 rosybrown
# Walking through big electric door 0.084 0.252 rosybrown
# Spam email 3e-07 9e-07 gray
# An email with long attachement 5e-05 0.00015000000000000001 gray
# Plastic bag (supermarket) 1e-05 3.0000000000000004e-05 rosybrown
# Plastic bag (reusable) 5e-05 0.00015000000000000001 rosybrown
# Apple (seasonal+local) 1e-05 3.0000000000000004e-05 green
# Apple (average) 8e-05 0.00024000000000000003 green
# Banana 8e-05 0.00024000000000000003 green
# An hour's TV 0.0001 0.00030000000000000003 rosybrown
# A mug of tea/coffee (black) 3e-05 9e-05 green
# A mug of tea/coffee (large latte) 0.0003 0.0009 green
# A mile by bus 0.0001 0.00030000000000000003 blue
# A mile by train 0.0002 0.0006000000000000001 blue
# 500 mL water bottle 0.0001 0.00030000000000000003 green
# Newspaper (Guardian Weekly) 0.0003 0.0009 rosybrown
# Newspaper (NYT Sunday) 0.003 0.009000000000000001 rosybrown
# Pint of beer 0.005 0.015 green
# Shower (electricity( 0.0005 0.0015 rosybrown
# A mile by car 1000.0 3000.0 blue
# A red rose (flown) 0.002 0.006 rosybrown
# pint of milk 0.0007 0.0021 green
# A bath 0.001 0.003 rosybrown
# Kg of rice 0.005 0.015 green
# A steak  0.002 0.006 green
# Light bulb (1 year) 0.5 1.5 rosybrown
# Pair of shoes 0.01 0.03 rosybrown
# A night out in hotel 0.024 0.07200000000000001 rosybrown
# A cell phone (1 year) 1.0 3.0 gray
# A mid distance flight  0.5 1.5 blue
# Christmas excess 0.25 0.75 rosybrown
# An iMac 0.75 2.25 gray
# A mortgage (per year) 0.8 2.4000000000000004 rosybrown
# Long flight 5.0 15.0 blue
# A person (UK per year) 15.0 45.0 orange
# A person (US per year) 30.0 90.0 orange
# A person (China per year) 3.0 9.0 orange
# A new car 10.0 30.0 blue
# A house  80.0 240.0 rosybrown
# Having a child 500.0 1500.0 orange
# 1 acre of deforastation 150.0 450.0 green
# A University 72000.0 216000.0 rosybrown
# A volcano (Mpount Etna) 1000000.0 3000000.0 orange
# World Cup 3000000.0 9000000.0 rosybrown
# A forest fire 200000000.0 600000000.0 orange
# A war 1000000000.0 3000000000.0 orange
# The world 50000000000.0 150000000000.0 orange
